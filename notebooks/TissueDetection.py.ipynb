# %% [markdown]
# # Tissue Detection for WSIs
#
# To patching or tiling, We need to seperate specimans from background in WSIs(Whole Slide Images).

# %% [markdown]
# ## Prerequisites
# `
# brew install openslide
# `
# `
# pip3 install -U matplotlib numpy openslide-python Pillow scikit-image scikit-learn scipy
# `

# %%
from openslide import OpenSlide, OpenSlideError

# %%
path = 'test_images/TEST_CERVIX_001.svs'
osr = OpenSlide(path)

# %%
osr.get_thumbnail((1024, 512))

# %%
import cv2
import numpy as np

def scaleContourDim(contours, scale):
    return [np.array(cont * scale, dtype='int32') for cont in contours]


def scaleHolesDim(contours, scale):
    return [[np.array(hole * scale, dtype = 'int32') for hole in holes] for holes in contours]
 

def segmentTissue(wsi_img, seg_level=0, sthresh=20, sthresh_up = 255, mthresh=7, close = 0, use_otsu=True, 
                  filter_params={'a_t':100, }, ref_patch_size=512,
                  exclude_ids=[], keep_ids=[]):
    """
        Segment the tissue via HSV -> Median thresholding -> Binary threshold
    """
    def _assertLevelDownsamples(wsi_img):
        level_downsamples = []
        dim_0 = wsi_img.level_dimensions[0]

        for downsample, dim in zip(wsi_img.level_downsamples, wsi_img.level_dimensions):
            estimated_downsample = (dim_0[0]/float(dim[0]), dim_0[1]/float(dim[1]))
            level_downsamples.append(estimated_downsample) if estimated_downsample != (downsample, downsample) else level_downsamples.append((downsample, downsample))

        return level_downsamples



    def _filter_contours(contours, hierarchy, filter_params):
        """
            Filter contours by: area.
        """
        filtered = []

        # find indices of foreground contours (parent == -1)
        hierarchy_1 = np.flatnonzero(hierarchy[:,1] == -1)
        all_holes = []

        # loop through foreground contour indices
        for cont_idx in hierarchy_1:
            # actual contour
            cont = contours[cont_idx]
            # indices of holes contained in this contour (children of parent contour)
            holes = np.flatnonzero(hierarchy[:, 1] == cont_idx)
            # take contour area (includes holes)
            a = cv2.contourArea(cont)
            # calculate the contour area of each hole
            hole_areas = [cv2.contourArea(contours[hole_idx]) for hole_idx in holes]
            # actual area of foreground contour region
            a = a - np.array(hole_areas).sum()
            if a == 0: continue
            if tuple((filter_params['a_t'],)) < tuple((a,)): 
                filtered.append(cont_idx)
                all_holes.append(holes)


        foreground_contours = [contours[cont_idx] for cont_idx in filtered]

        hole_contours = []

        for hole_ids in all_holes:
            unfiltered_holes = [contours[idx] for idx in hole_ids ]
            unfilered_holes = sorted(unfiltered_holes, key=cv2.contourArea, reverse=True)
            # take max_n_holes largest holes by area
            unfilered_holes = unfilered_holes[:filter_params['max_n_holes']]
            filtered_holes = []

            # filter these holes
            for hole in unfilered_holes:
                if cv2.contourArea(hole) > filter_params['a_h']:
                    filtered_holes.append(hole)

            hole_contours.append(filtered_holes)

        return foreground_contours, hole_contours

    img = np.array(wsi_img.read_region((0,0), seg_level, wsi_img.level_dimensions[seg_level]))
    img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)  # Convert to HSV space
    img_med = cv2.medianBlur(img_hsv[:,:,1], mthresh)  # Apply median blurring


    # Thresholding
    if use_otsu:
        _, img_otsu = cv2.threshold(img_med, 0, sthresh_up, cv2.THRESH_OTSU+cv2.THRESH_BINARY)
    else:
        _, img_otsu = cv2.threshold(img_med, sthresh, sthresh_up, cv2.THRESH_BINARY)

    # Morphological closing
    if close > 0:
        kernel = np.ones((close, close), np.uint8)
        img_otsu = cv2.morphologyEx(img_otsu, cv2.MORPH_CLOSE, kernel)                 
    
    level_downsamples = _assertLevelDownsamples(wsi_img)
    scale = level_downsamples[seg_level]
    scaled_ref_patch_area = int(ref_patch_size**2 / (scale[0] * scale[1]))
    filter_params = filter_params.copy()
    filter_params['a_t'] = filter_params['a_t'] * scaled_ref_patch_area
    filter_params['a_h'] = filter_params['a_h'] * scaled_ref_patch_area

    # Find and filter contours
    contours, hierarchy = cv2.findContours(img_otsu, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE) # Find contours 
    hierarchy = np.squeeze(hierarchy, axis=(0,))[:, 2:]
    if filter_params: foreground_contours, hole_contours = _filter_contours(contours, hierarchy, filter_params)  # Necessary for filtering out artifacts

    contours_tissue = scaleContourDim(foreground_contours, scale)
    holes_tissue = scaleHolesDim(hole_contours, scale)

    #exclude_ids = [0,7,9]
    if len(keep_ids) > 0:
        contour_ids = set(keep_ids) - set(exclude_ids)
    else:
        contour_ids = set(np.arange(len(contours_tissue))) - set(exclude_ids)

    contours_tissue = [contours_tissue[i] for i in contour_ids]
    holes_tissue = [holes_tissue[i] for i in contour_ids]
    
    return contours_tissue, holes_tissue

# %%
# filter_params description
# a_t: area_threshold(pass the more value)
# a_h: hole_threshold(pass the lower value)
ct, ht = segmentTissue(osr, filter_params={'a_t':10, 'a_h': 16, 'max_n_holes':5 })

# %%
len(ct)

# %%
x, y = osr.dimensions
target_x = 512
target_y = int(y/(x/target_x))
divisor = (x/target_x, y/target_y)
cnt = []
for i in ct:
    t = np.floor_divide(i, divisor)
    x = np.array(t, dtype='int32')
    cnt.append(x)

# %%
import matplotlib.pylab as plt

numpy_image=np.array(osr.get_thumbnail((512, 105)))  

# convert to a openCV2 image and convert from RGB to BGR format
opencv_image=cv2.cvtColor(numpy_image, cv2.COLOR_RGB2BGR)

cv2.drawContours(opencv_image, cnt, -1, (0, 255, 0), 1)
plt.figure(figsize = (512,105))
plt.imshow(opencv_image)

# %% [markdown]
# Patching process

# %%
# other imports
import cv2

class Contour_Checking_fn(object):
    # Defining __call__ method 
    def __call__(self, pt): 
        raise NotImplementedError

class isInContourV1(Contour_Checking_fn):
    def __init__(self, contour):
        self.cont = contour

    def __call__(self, pt): 
        return 1 if cv2.pointPolygonTest(self.cont, pt, False) >= 0 else 0

class isInContourV2(Contour_Checking_fn):
    def __init__(self, contour, patch_size):
        self.cont = contour
        self.patch_size = patch_size

    def __call__(self, pt): 
        return 1 if cv2.pointPolygonTest(self.cont, (pt[0]+self.patch_size//2, pt[1]+self.patch_size//2), False) >= 0 else 0

# Easy version of 4pt contour checking function - 1 of 4 points need to be in the contour for test to pass
class isInContourV3_Easy(Contour_Checking_fn):
    def __init__(self, contour, patch_size, center_shift=0.5):
        self.cont = contour
        self.patch_size = patch_size
        self.shift = int(patch_size//2*center_shift)
    def __call__(self, pt): 
        center = (pt[0]+self.patch_size//2, pt[1]+self.patch_size//2)
        if self.shift > 0:
            all_points = [(center[0]-self.shift, center[1]-self.shift),
                          (center[0]+self.shift, center[1]+self.shift),
                          (center[0]+self.shift, center[1]-self.shift),
                          (center[0]-self.shift, center[1]+self.shift)
                          ]
        else:
            all_points = [center]

        for points in all_points:
            if cv2.pointPolygonTest(self.cont, points, False) >= 0:
                return 1
        return 0

# Hard version of 4pt contour checking function - all 4 points need to be in the contour for test to pass
class isInContourV3_Hard(Contour_Checking_fn):
    def __init__(self, contour, patch_size, center_shift=0.5):
        self.cont = contour
        self.patch_size = patch_size
        self.shift = int(patch_size//2*center_shift)
    def __call__(self, pt): 
        center = (pt[0]+self.patch_size//2, pt[1]+self.patch_size//2)
        if self.shift > 0:
            all_points = [(center[0]-self.shift, center[1]-self.shift),
                          (center[0]+self.shift, center[1]+self.shift),
                          (center[0]+self.shift, center[1]-self.shift),
                          (center[0]-self.shift, center[1]+self.shift)
                          ]
        else:
            all_points = [center]

        for points in all_points:
            if cv2.pointPolygonTest(self.cont, points, False) < 0:
                return 0
        return 1

# %%
def isWhitePatch(patch, satThresh=5):
    patch_hsv = cv2.cvtColor(patch, cv2.COLOR_RGB2HSV)
    return True if np.mean(patch_hsv[:,:,1]) < satThresh else False

def isBlackPatch(patch, rgbThresh=40):
    return True if np.all(np.mean(patch, axis = (0,1)) < rgbThresh) else False

# %%
def isInHoles(holes, pt, patch_size):
    for hole in holes:
        if cv2.pointPolygonTest(hole, (pt[0]+patch_size/2, pt[1]+patch_size/2), False) > 0:
            return 1

    return 0


def isInContours(cont_check_fn, pt, holes=None, patch_size=256):
    if cont_check_fn(pt):
        if holes is not None:
            return not isInHoles(holes, pt, patch_size)
        else:
            return 1
    return 0


def _getPatchGenerator(wsi_img, cont, cont_idx, ht, patch_level, save_path, patch_size=256, step_size=256, custom_downsample=1,
    white_black=True, white_thresh=15, black_thresh=50, contour_fn='four_pt', use_padding=True):
    start_x, start_y, w, h = cv2.boundingRect(cont) if cont is not None else (0, 0, wsi_img.level_dimensions[patch_level][0], wsi_img.level_dimensions[patch_level][1])
    print("Bounding Box:", start_x, start_y, w, h)
    print("Contour Area:", cv2.contourArea(cont))

    
    def _assertLevelDownsamples(wsi_img):
        level_downsamples = []
        dim_0 = wsi_img.level_dimensions[0]

        for downsample, dim in zip(wsi_img.level_downsamples, wsi_img.level_dimensions):
            estimated_downsample = (dim_0[0]/float(dim[0]), dim_0[1]/float(dim[1]))
            level_downsamples.append(estimated_downsample) if estimated_downsample != (downsample, downsample) else level_downsamples.append((downsample, downsample))

        return level_downsamples


    if custom_downsample > 1:
        assert custom_downsample == 2 
        target_patch_size = patch_size
        patch_size = target_patch_size * 2
        step_size = step_size * 2
        print("Custom Downsample: {}, Patching at {} x {}, But Final Patch Size is {} x {}".format(custom_downsample, patch_size, patch_size, 
            target_patch_size, target_patch_size))
    
    level_downsamples = _assertLevelDownsamples(wsi_img)
    patch_downsample = (int(level_downsamples[patch_level][0]), int(level_downsamples[patch_level][1]))
    ref_patch_size = (patch_size*patch_downsample[0], patch_size*patch_downsample[1])

    step_size_x = step_size * patch_downsample[0]
    step_size_y = step_size * patch_downsample[1]

    if isinstance(contour_fn, str):
        if contour_fn == 'four_pt':
            cont_check_fn = isInContourV3_Easy(contour=cont, patch_size=ref_patch_size[0], center_shift=0.5)
        elif contour_fn == 'four_pt_hard':
            cont_check_fn = isInContourV3_Hard(contour=cont, patch_size=ref_patch_size[0], center_shift=0.5)
        elif contour_fn == 'center':
            cont_check_fn = isInContourV2(contour=cont, patch_size=ref_patch_size[0])
        elif contour_fn == 'basic':
            cont_check_fn = isInContourV1(contour=cont)
        else:
            raise NotImplementedError
    else:
        assert isinstance(contour_fn, Contour_Checking_fn)
        cont_check_fn = contour_fn

    img_w, img_h = wsi_img.level_dimensions[0]
    if use_padding:
        stop_y = start_y+h
        stop_x = start_x+w
    else:
        stop_y = min(start_y+h, img_h-ref_patch_size[1])
        stop_x = min(start_x+w, img_w-ref_patch_size[0])

    count = 0
    for y in range(start_y, stop_y, step_size_y):
        for x in range(start_x, stop_x, step_size_x):

            if not isInContours(cont_check_fn, (x,y), ht[cont_idx], ref_patch_size[0]): #point not inside contour and its associated holes
                continue    

            count+=1
            patch_PIL = wsi_img.read_region((x,y), patch_level, (patch_size, patch_size)).convert('RGB')
            if custom_downsample > 1:
                patch_PIL = patch_PIL.resize((target_patch_size, target_patch_size))

            if white_black:
                if isBlackPatch(np.array(patch_PIL), rgbThresh=black_thresh) or isWhitePatch(np.array(patch_PIL), satThresh=white_thresh): 
                    continue

            patch_info = {'x':x // (patch_downsample[0] * custom_downsample), 
                          'y':y // (patch_downsample[1] * custom_downsample), 
                          'cont_idx':cont_idx, 'patch_level':patch_level, 
                          'downsample': level_downsamples[patch_level], 
                          'downsampled_level_dim': tuple(np.array(wsi_img.level_dimensions[patch_level])//custom_downsample), 
                          'level_dim': wsi_img.level_dimensions[patch_level],
                          'patch_PIL':patch_PIL, 
                          #'name':self.name, 
                          'save_path':save_path}

            yield patch_info


    print("patches extracted: {}".format(count))

# %%
'''Patching params description
custom_downsample: 1 or 2
'''
from PIL import Image
patching_param = {'patch_level': 0, 
                  'patch_size': 512, 
                  'step_size': 512, 
                  'save_path': 'test_output', 
                  'custom_downsample': 1}
_counter = 0
for idx, cont in enumerate(ct):
    patch_gen = _getPatchGenerator(osr, cont, idx, ht, contour_fn='four_pt', **patching_param)
#     patch_gen = _getPatchGenerator(osr, cont, idx, ht, contour_fn='four_pt_hard', **patching_param)

    try:
        first_patch = next(patch_gen)

    # empty contour, continue
    except StopIteration:
        print(f'StopIteration Error')
        continue

    for patch in patch_gen:
        patch['patch_PIL'].save(f"{patch['save_path']}/TestPatch_{_counter}.png", "png")
#         Image.save(patch['save_path'] + "TestPatch" + _counter, "JPEG")
        _counter += 1        
#         with Image.open(patch['patch_PIL']) as im:
#             im.thumbnail(size)
#             im.save(patch['save_path'] + "TestPatch", _counter, "JPEG")
#             _couter += 1

# %%
from os import walk

def get_list(dir_) -> list:
    list_ = []
#     for (dirpath, dirnames, filenames) in walk(dir_):
    for (_, _, filenames) in walk(dir_):
        list_ = filenames
    return list_

# %%
dataset_path = '/data/kwkim/aadw/dataset/bladder/raw_test'

# %%
list_ = get_list(dataset_path)

# %%
len(list_)
# Out:
# 23

# %%
filter_params={'a_t':10, 'a_h': 16, 'max_n_holes':5 }
patching_param = {'patch_level': 0, 
                  'patch_size': 1024, 
                  'step_size': 1024, 
                  'save_path': '/data/kwkim/aadw/dataset/bladder/patches-test-1024', 
                  'custom_downsample': 1}

# %%
import os
if os.path.exists(patching_param['save_path']) is False:
    os.mkdir(patching_param['save_path'])
    
for i in list_:
    try:
        os.mkdir(os.path.join(patching_param['save_path'], os.path.splitext(i)[0]))
    except:
        continue

# %%
# %%time
import time
from tqdm import tqdm
for file_ in tqdm(list_):
    try:
        osr = OpenSlide(os.path.join(dataset_path, file_))
    except:
        print(f'Could not open: {file_}')
        continue
    
    start_t = time.time()
    ct, ht = segmentTissue(osr, filter_params=filter_params)    

    end_t = time.time()
    print(f'[D] Elapsed(Tissue detection): {end_t-start_t}s')
    filename = os.path.basename(file_).split('.')[0]
#     if os.path.exists(os.join.path(patching_param['save_path'], filename)) is False:
#         os.mkdir(os.join.path(patching_param['save_path'], filename))
    start_t = time.time()
    
    for idx, cont in enumerate(ct):
#         patch_gen = _getPatchGenerator(osr, cont, idx, ht, contour_fn='four_pt', **patching_param)
        patch_gen = _getPatchGenerator(osr, cont, idx, ht, contour_fn='four_pt_hard', **patching_param)

        try:
            first_patch = next(patch_gen)

        # empty contour, continue
        except StopIteration:
            print(f'StopIteration Error')
            continue
        
        for patch in patch_gen:
            patch['patch_PIL'].save(f"{patch['save_path']}/{filename}/{filename}_x_{patch['x']}_y_{patch['y']}.png", "png")
    end_t = time.time()
    print(f'[D] Elapsed(Generate patches): {end_t-start_t}s')
    osr.close()
# Out:
#   0%|                                                                                                       | 0/23 [00:00<?, ?it/s]
# [D] Elapsed(Tissue detection): 102.32381105422974s
# Bounding Box: 8403 22953 6239 5904
# Contour Area: 17303038.0
# patches extracted: 12
# Bounding Box: 22333 21998 2576 4525
# Contour Area: 5192546.5
# patches extracted: 5
# Bounding Box: 14733 21826 6214 6548
# Contour Area: 23390904.0
# patches extracted: 16
# Bounding Box: 24464 18975 5367 3929
# Contour Area: 8215303.5
# patches extracted: 3
# Bounding Box: 12272 15121 9244 7016
# Contour Area: 41226878.0
# patches extracted: 30
# Bounding Box: 22083 11974 5914 8107
# Contour Area: 31563113.5
# patches extracted: 21
# Bounding Box: 5839 10383 7728 9179
# Contour Area: 29799544.0
# patches extracted: 22
# Bounding Box: 4805 6359 2959 3848
# Contour Area: 6323984.0
# patches extracted: 3
# Bounding Box: 12764 6215 7231 9739
# Contour Area: 35945338.0
# patches extracted: 23
# Bounding Box: 3378 5010 9386 10524
# Contour Area: 35599955.0
# patches extracted: 23
# Bounding Box: 11725 3470 5722 3493
# Contour Area: 10004928.5
# patches extracted: 6
# Bounding Box: 19768 416 6103 6133
# Contour Area: 16569642.5
#   4%|████                                                                                        | 1/23 [02:44<1:00:19, 164.54s/it]
# patches extracted: 6
# [D] Elapsed(Generate patches): 62.139723777770996s
# [D] Elapsed(Tissue detection): 1463.3163831233978s
# Bounding Box: 43823 32315 2563 7329
# Contour Area: 4310393.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 21506 32130 10476 7633
# Contour Area: 37783144.0
# patches extracted: 23
# Bounding Box: 31706 31628 5483 3417
# Contour Area: 12944329.0
# patches extracted: 9
# Bounding Box: 6397 31146 4040 10453
# Contour Area: 23176432.5
# patches extracted: 17
# Bounding Box: 40480 30241 5209 4382
# Contour Area: 9701354.5
# patches extracted: 3
# Bounding Box: 15834 29144 3572 2916
# Contour Area: 4570024.5
# patches extracted: 1
# Bounding Box: 5924 28281 3772 4999
# Contour Area: 7179322.0
# patches extracted: 4
# Bounding Box: 21260 27835 4678 3160
# Contour Area: 8663475.5
# patches extracted: 5
# Bounding Box: 47490 24720 14884 11568
# Contour Area: 51124366.5
# patches extracted: 29
# Bounding Box: 9576 24535 3779 3742
# Contour Area: 5389616.0
# patches extracted: 2
# Bounding Box: 28169 24140 12124 7527
# Contour Area: 57638249.0
# patches extracted: 45
# Bounding Box: 13172 24095 5031 3533
# Contour Area: 9840061.0
# patches extracted: 4
# Bounding Box: 41551 24049 5403 5951
# Contour Area: 17233061.0
# patches extracted: 11
# Bounding Box: 18159 23620 3484 4283
# Contour Area: 9819556.5
# patches extracted: 7
# Bounding Box: 2939 20277 3170 3138
# Contour Area: 6348003.5
# patches extracted: 3
# Bounding Box: 46577 19137 12067 7454
# Contour Area: 45150115.0
# patches extracted: 33
# Bounding Box: 45077 18831 2141 4436
# Contour Area: 4750275.0
# patches extracted: 2
# Bounding Box: 53112 18731 10253 5430
# Contour Area: 23185276.5
# patches extracted: 13
# Bounding Box: 40472 18352 4510 7395
# Contour Area: 15443307.0
# patches extracted: 8
# Bounding Box: 8632 16784 13291 7878
# Contour Area: 39035840.0
# patches extracted: 26
# Bounding Box: 25734 15989 14547 8608
# Contour Area: 65172750.5
# patches extracted: 47
# Bounding Box: 11533 11773 6370 5628
# Contour Area: 16396758.5
# patches extracted: 9
# Bounding Box: 26440 11557 3047 2219
# Contour Area: 4643238.0
# patches extracted: 2
# Bounding Box: 16564 11222 3502 4038
# Contour Area: 6371575.5
# patches extracted: 2
# Bounding Box: 44818 11125 6405 7429
# Contour Area: 22648942.0
# patches extracted: 19
# Bounding Box: 20346 10565 8787 8412
# Contour Area: 39071596.0
# patches extracted: 26
# Bounding Box: 51127 10424 8948 6783
# Contour Area: 24915427.5
# patches extracted: 14
# Bounding Box: 29288 10264 4575 7925
# Contour Area: 15922532.5
# patches extracted: 6
# Bounding Box: 2775 9286 2392 3399
# Contour Area: 5037032.5
# patches extracted: 2
# Bounding Box: 47996 9089 2677 3046
# Contour Area: 3260090.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 36688 6896 9955 6014
# Contour Area: 21519255.0
# patches extracted: 9
# Bounding Box: 49222 4780 4193 5761
# Contour Area: 6553429.0
# patches extracted: 2
# Bounding Box: 9386 3476 8396 7722
# Contour Area: 30934130.0
# patches extracted: 20
# Bounding Box: 24089 2308 13810 8725
# Contour Area: 53786944.0
#   9%|███████▉                                                                                   | 2/23 [30:01<6:00:44, 1030.69s/it]
# patches extracted: 37
# [D] Elapsed(Generate patches): 173.6024079322815s
# [D] Elapsed(Tissue detection): 875.3735139369965s
# Bounding Box: 9462 37429 12750 5891
# Contour Area: 32565889.0
# patches extracted: 22
# Bounding Box: 17412 35376 5220 3329
# Contour Area: 5600072.5
# patches extracted: 3
# Bounding Box: 40558 34963 10507 8190
# Contour Area: 22840503.0
# patches extracted: 11
# Bounding Box: 28404 34884 2306 4348
# Contour Area: 4467178.5
# patches extracted: 2
# Bounding Box: 29486 33775 10800 11237
# Contour Area: 68693942.5
# patches extracted: 56
# Bounding Box: 36552 25335 17243 6743
# Contour Area: 70234755.5
# patches extracted: 55
# Bounding Box: 30224 25020 7182 8502
# Contour Area: 36307067.0
# patches extracted: 29
# Bounding Box: 23574 24772 4496 5004
# Contour Area: 13595989.5
# patches extracted: 9
# Bounding Box: 28378 20120 19651 6966
# Contour Area: 81633530.0
# patches extracted: 63
# Bounding Box: 21490 19646 3067 18444
# Contour Area: 28753819.5
# patches extracted: 17
# Bounding Box: 17920 16269 3825 3788
# Contour Area: 9479794.5
# patches extracted: 8
# Bounding Box: 34368 14756 5335 5167
# Contour Area: 10690170.5
# patches extracted: 5
# Bounding Box: 31577 14519 4476 4051
# Contour Area: 3649357.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 2575 12869 20149 22964
# Contour Area: 123716091.5
# patches extracted: 89
# Bounding Box: 13407 8406 10739 9483
# Contour Area: 35839910.0
# patches extracted: 27
# Bounding Box: 38349 5682 19742 9776
# Contour Area: 66129467.0
# patches extracted: 40
# Bounding Box: 40425 5105 7843 5719
# Contour Area: 20509135.0
# patches extracted: 13
# Bounding Box: 11216 4171 8933 12445
# Contour Area: 33548673.0
# patches extracted: 11
# Bounding Box: 43276 3549 3601 2402
# Contour Area: 4443021.0
# patches extracted: 2
# Bounding Box: 32862 2559 7532 12646
# Contour Area: 14776309.0
# patches extracted: 6
# Bounding Box: 22259 14 11433 7732
# Contour Area: 39567224.5
#  13%|███████████▊                                                                               | 3/23 [47:49<5:49:13, 1047.68s/it]
# patches extracted: 26
# [D] Elapsed(Generate patches): 192.42181277275085s
# [D] Elapsed(Tissue detection): 153.09390497207642s
# Bounding Box: 26632 28017 3059 7863
# Contour Area: 11795234.0
# patches extracted: 7
# Bounding Box: 32078 24522 5211 4192
# Contour Area: 9399318.5
# patches extracted: 6
# Bounding Box: 31080 19766 4506 3462
# Contour Area: 7386280.0
# patches extracted: 3
# Bounding Box: 11065 19348 15554 10980
# Contour Area: 100714376.5
# patches extracted: 71
# Bounding Box: 39446 13990 7417 7408
# Contour Area: 35634343.0
# patches extracted: 30
# Bounding Box: 1403 10917 9208 12225
# Contour Area: 70226959.0
# patches extracted: 53
# Bounding Box: 15789 6810 3603 3473
# Contour Area: 8199367.5
# patches extracted: 5
# Bounding Box: 28769 4145 6795 13196
# Contour Area: 53072034.0
# patches extracted: 40
# Bounding Box: 8720 3046 6514 6250
# Contour Area: 21109362.0
# patches extracted: 15
# Bounding Box: 15622 2582 10619 14049
# Contour Area: 64561650.0
# patches extracted: 48
# Bounding Box: 30855 1423 3973 2807
# Contour Area: 6339659.0
#  17%|████████████████                                                                            | 4/23 [52:10<3:53:28, 737.26s/it]
# patches extracted: 2
# [D] Elapsed(Generate patches): 108.18919968605042s
# [D] Elapsed(Tissue detection): 834.1946051120758s
# Bounding Box: 16682 39152 2782 3225
# Contour Area: 3599021.5
# patches extracted: 1
# Bounding Box: 40948 36078 3469 2533
# Contour Area: 3618828.5
# patches extracted: 2
# Bounding Box: 43760 35989 5719 5554
# Contour Area: 13224411.0
# patches extracted: 6
# Bounding Box: 8756 33945 2715 6504
# Contour Area: 4995976.0
# patches extracted: 2
# Bounding Box: 14510 33731 3667 4284
# Contour Area: 6441816.5
# patches extracted: 2
# Bounding Box: 32859 33619 8448 5316
# Contour Area: 30675038.0
# patches extracted: 20
# Bounding Box: 2503 28668 8662 8977
# Contour Area: 30404128.5
# patches extracted: 16
# Bounding Box: 34630 27401 8250 7688
# Contour Area: 24068726.5
# patches extracted: 14
# Bounding Box: 2831 25636 8826 3906
# Contour Area: 11339744.5
# patches extracted: 2
# Bounding Box: 35432 25198 8705 6221
# Contour Area: 13195623.0
# patches extracted: 6
# Bounding Box: 49018 24237 4405 3048
# Contour Area: 5869545.0
# patches extracted: 3
# Bounding Box: 26898 16498 7674 10498
# Contour Area: 35202136.0
# patches extracted: 21
# Bounding Box: 16108 15843 19985 29062
# Contour Area: 216432229.5
# patches extracted: 142
# Bounding Box: 33626 15627 4699 6542
# Contour Area: 11023385.0
# patches extracted: 1
# Bounding Box: 5566 15353 4204 6573
# Contour Area: 17356457.5
# patches extracted: 12
# Bounding Box: 38290 15056 9059 11514
# Contour Area: 49984217.5
# patches extracted: 36
# Bounding Box: 10178 13997 8674 10931
# Contour Area: 41773921.5
# patches extracted: 27
# Bounding Box: 39443 12949 2272 3442
# Contour Area: 3896637.0
# patches extracted: 1
# Bounding Box: 34906 11776 6010 6305
# Contour Area: 15093601.5
# patches extracted: 6
# Bounding Box: 45309 11169 4381 3127
# Contour Area: 6705425.5
# patches extracted: 2
# Bounding Box: 49872 11150 12906 14771
# Contour Area: 90947905.5
# patches extracted: 66
# Bounding Box: 52576 10870 2527 5193
# Contour Area: 4437933.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 4557 10708 4102 4054
# Contour Area: 7684498.5
# patches extracted: 2
# Bounding Box: 37797 8134 2864 3620
# Contour Area: 5734900.0
# patches extracted: 2
# Bounding Box: 45560 7518 4405 4575
# Contour Area: 8243123.0
# patches extracted: 4
# Bounding Box: 58291 5785 3597 3555
# Contour Area: 5946365.0
# patches extracted: 1
# Bounding Box: 41024 5465 7508 7784
# Contour Area: 28409912.0
# patches extracted: 18
# Bounding Box: 8550 4594 6853 4665
# Contour Area: 14307071.5
# patches extracted: 4
# Bounding Box: 24035 4206 11478 11696
# Contour Area: 55547686.5
# patches extracted: 28
# Bounding Box: 36239 2824 7153 3624
# Contour Area: 15027333.0
# patches extracted: 10
# Bounding Box: 47930 2354 3532 6631
# Contour Area: 13244453.5
# patches extracted: 6
# Bounding Box: 14421 615 10502 16032
# Contour Area: 67196955.0
# patches extracted: 38
# Bounding Box: 9170 174 5314 3937
# Contour Area: 5634856.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 42444 0 3813 3338
# Contour Area: 8009002.5
#  22%|███████████████████▌                                                                      | 5/23 [1:09:23<4:13:06, 843.72s/it]
# patches extracted: 4
# [D] Elapsed(Generate patches): 198.21491718292236s
# [D] Elapsed(Tissue detection): 1024.9946236610413s
# Bounding Box: 16373 39579 3598 4344
# Contour Area: 9258139.0
# patches extracted: 6
# Bounding Box: 23267 38189 4632 7100
# Contour Area: 21866476.5
# patches extracted: 13
# Bounding Box: 49125 37215 6224 7761
# Contour Area: 23721948.5
# patches extracted: 11
# Bounding Box: 55786 37157 5170 4960
# Contour Area: 12008967.0
# patches extracted: 4
# Bounding Box: 40052 36432 4015 3422
# Contour Area: 6095791.0
# patches extracted: 1
# Bounding Box: 52752 36302 4172 2811
# Contour Area: 5440120.0
# patches extracted: 2
# Bounding Box: 12017 33364 12149 11925
# Contour Area: 76387514.0
# patches extracted: 53
# Bounding Box: 39675 32047 4460 4166
# Contour Area: 9261429.5
# patches extracted: 4
# Bounding Box: 43092 30879 8074 11887
# Contour Area: 35131084.0
# patches extracted: 15
# Bounding Box: 46503 30528 3920 4498
# Contour Area: 6520909.0
# patches extracted: 3
# Bounding Box: 9863 25844 14815 8653
# Contour Area: 66042692.5
# patches extracted: 39
# Bounding Box: 48335 24514 8635 9895
# Contour Area: 33294693.5
# patches extracted: 17
# Bounding Box: 41956 24464 4619 3544
# Contour Area: 6568444.0
# patches extracted: 1
# Bounding Box: 49876 23342 2170 3539
# Contour Area: 3277878.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 31048 22399 13590 14013
# Contour Area: 57366269.0
# patches extracted: 24
# Bounding Box: 12946 20977 2344 2686
# Contour Area: 3350347.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 26799 19301 3365 6737
# Contour Area: 7297254.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 20925 18908 10303 18076
# Contour Area: 83257393.0
# patches extracted: 55
# Bounding Box: 2081 18515 6217 8606
# Contour Area: 23745344.0
# patches extracted: 13
# Bounding Box: 42562 17984 6931 12614
# Contour Area: 26998032.5
# patches extracted: 6
# Bounding Box: 51801 17909 6841 6285
# Contour Area: 21052738.5
# patches extracted: 13
# Bounding Box: 44316 15364 5114 6008
# Contour Area: 13300269.0
# patches extracted: 8
# Bounding Box: 30380 15122 7126 7721
# Contour Area: 21468619.0
# patches extracted: 9
# Bounding Box: 4026 14628 4370 5674
# Contour Area: 10626309.5
# patches extracted: 6
# Bounding Box: 8880 14115 3153 4979
# Contour Area: 7814256.5
# patches extracted: 1
# Bounding Box: 11461 13561 8120 12550
# Contour Area: 47217135.5
# patches extracted: 29
# Bounding Box: 27035 13554 3275 2857
# Contour Area: 3817454.0
# patches extracted: 1
# Bounding Box: 44353 11950 3138 3432
# Contour Area: 4441589.0
# patches extracted: 2
# Bounding Box: 49543 11936 5408 5253
# Contour Area: 15188447.5
# patches extracted: 8
# Bounding Box: 36649 10916 8158 8718
# Contour Area: 28769764.0
# patches extracted: 12
# Bounding Box: 9031 10481 2633 4002
# Contour Area: 5450642.0
# patches extracted: 2
# Bounding Box: 10988 8248 6813 6313
# Contour Area: 21052212.0
# patches extracted: 11
# Bounding Box: 45787 8135 4607 3662
# Contour Area: 10266528.0
# patches extracted: 6
# Bounding Box: 1647 6521 7114 8121
# Contour Area: 31417314.0
# patches extracted: 21
# Bounding Box: 31008 6459 4715 7694
# Contour Area: 17437954.0
# patches extracted: 10
# Bounding Box: 35429 5984 3413 2069
# Contour Area: 3720183.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 16107 3986 16329 17325
# Contour Area: 92866251.5
# patches extracted: 47
# Bounding Box: 19082 1402 4951 5833
# Contour Area: 14729023.0
# patches extracted: 8
# Bounding Box: 23852 779 3307 6341
# Contour Area: 8006500.0
# patches extracted: 1
# Bounding Box: 51961 0 10304 13058
# Contour Area: 85288755.5
# patches extracted: 64
# Bounding Box: 27771 0 17275 14088
# Contour Area: 93971456.0
# patches extracted: 52
# Bounding Box: 19366 0 3470 3709
# Contour Area: 7356159.0
#  26%|███████████████████████▍                                                                  | 6/23 [1:30:17<4:38:34, 983.18s/it]
# patches extracted: 3
# [D] Elapsed(Generate patches): 228.7783899307251s
# [D] Elapsed(Tissue detection): 811.1859972476959s
# Bounding Box: 6996 33539 5257 4603
# Contour Area: 14624677.0
# patches extracted: 6
# Bounding Box: 16740 33013 2687 3217
# Contour Area: 3893688.0
# patches extracted: 1
# Bounding Box: 11814 32673 5066 5705
# Contour Area: 12926712.0
# patches extracted: 6
# Bounding Box: 40131 30457 2947 4783
# Contour Area: 6654650.0
# patches extracted: 3
# Bounding Box: 3163 29754 6840 7275
# Contour Area: 17262094.5
# patches extracted: 10
# Bounding Box: 10225 29172 4993 4665
# Contour Area: 10916157.0
# patches extracted: 4
# Bounding Box: 33120 27960 8461 12151
# Contour Area: 25655895.5
# patches extracted: 10
# Bounding Box: 23313 26345 5929 4040
# Contour Area: 9468802.0
# patches extracted: 4
# Bounding Box: 41140 25660 4118 3990
# Contour Area: 4290770.0
# patches extracted: 1
# Bounding Box: 18987 22760 13667 7048
# Contour Area: 34418150.5
# patches extracted: 23
# Bounding Box: 32994 22539 5101 6744
# Contour Area: 19096645.5
# patches extracted: 11
# Bounding Box: 23183 20838 3538 2334
# Contour Area: 3456167.5
# patches extracted: 1
# Bounding Box: 25652 20128 4673 3949
# Contour Area: 6609981.0
# patches extracted: 2
# Bounding Box: 30210 19065 2636 3725
# Contour Area: 4028213.0
# patches extracted: 1
# Bounding Box: 21389 18826 1919 2892
# Contour Area: 3503602.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 36991 16248 3868 5421
# Contour Area: 14249775.0
# patches extracted: 8
# Bounding Box: 3798 15534 5811 6031
# Contour Area: 18516304.5
# patches extracted: 6
# Bounding Box: 32223 14806 5634 9290
# Contour Area: 17559065.0
# patches extracted: 5
# Bounding Box: 11276 14366 3972 8379
# Contour Area: 14011578.5
# patches extracted: 6
# Bounding Box: 10575 10382 4558 4198
# Contour Area: 5598245.0
# patches extracted: 2
# Bounding Box: 15938 8058 10273 13562
# Contour Area: 76349675.0
# patches extracted: 49
# Bounding Box: 25547 6012 5049 6079
# Contour Area: 16745437.0
# patches extracted: 8
# Bounding Box: 8590 5728 5362 5893
# Contour Area: 14905318.5
# patches extracted: 8
# Bounding Box: 18394 4149 4870 4048
# Contour Area: 8924096.0
# patches extracted: 3
# Bounding Box: 10772 3291 7479 6218
# Contour Area: 12151112.5
# patches extracted: 5
# Bounding Box: 21246 2585 5033 3287
# Contour Area: 6449291.0
# patches extracted: 1
# Bounding Box: 15450 988 6793 4802
# Contour Area: 10775078.0
#  30%|███████████████████████████▍                                                              | 7/23 [1:44:53<4:12:49, 948.09s/it]
# patches extracted: 3
# [D] Elapsed(Generate patches): 64.5951521396637s
# [D] Elapsed(Tissue detection): 692.2699108123779s
# Bounding Box: 11157 38143 2414 3434
# Contour Area: 4590148.0
# patches extracted: 2
# Bounding Box: 22067 36826 4867 5257
# Contour Area: 8422976.5
# patches extracted: 3
# Bounding Box: 34507 31796 2790 4759
# Contour Area: 5044727.0
# patches extracted: 1
# Bounding Box: 27525 31106 3705 2601
# Contour Area: 4134023.0
# patches extracted: 1
# Bounding Box: 5502 28073 3074 3268
# Contour Area: 3595615.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 6277 25813 8056 4817
# Contour Area: 18999069.5
# patches extracted: 6
# Bounding Box: 13612 23714 5380 5147
# Contour Area: 13256255.5
# patches extracted: 8
# Bounding Box: 32149 20844 21898 18352
# Contour Area: 197213803.0
# patches extracted: 142
# Bounding Box: 15414 20089 3244 3670
# Contour Area: 6381247.0
# patches extracted: 2
# Bounding Box: 18886 17995 13809 20560
# Contour Area: 85030404.0
# patches extracted: 47
# Bounding Box: 2842 16750 11713 7353
# Contour Area: 44338126.5
# patches extracted: 28
# Bounding Box: 39562 16559 5892 5480
# Contour Area: 12490548.5
# patches extracted: 6
# Bounding Box: 16112 16508 5197 5646
# Contour Area: 14295083.0
# patches extracted: 7
# Bounding Box: 25169 15448 10432 3085
# Contour Area: 15263374.0
# patches extracted: 8
# Bounding Box: 44274 15304 3666 3389
# Contour Area: 4910673.5
# patches extracted: 2
# Bounding Box: 47508 13526 6263 6273
# Contour Area: 17319196.5
# patches extracted: 9
# Bounding Box: 14355 13441 7171 3684
# Contour Area: 14501968.0
# patches extracted: 6
# Bounding Box: 3156 13110 3752 3996
# Contour Area: 7064400.0
# patches extracted: 2
# Bounding Box: 5853 11854 6008 4974
# Contour Area: 14624002.5
# patches extracted: 8
# Bounding Box: 50388 10536 4863 4662
# Contour Area: 9091781.0
# patches extracted: 3
# Bounding Box: 17523 10380 8696 6546
# Contour Area: 19278241.0
# patches extracted: 11
# Bounding Box: 52524 8110 11400 24713
# Contour Area: 152560873.0
# patches extracted: 118
# Bounding Box: 1024 5842 5018 3413
# Contour Area: 9073768.0
# patches extracted: 4
# Bounding Box: 4131 5684 5152 5536
# Contour Area: 10910083.5
# patches extracted: 3
# Bounding Box: 11347 5659 7628 4562
# Contour Area: 17335201.5
# patches extracted: 9
# Bounding Box: 28796 4025 10397 12802
# Contour Area: 70005707.0
# patches extracted: 43
# Bounding Box: 40033 3193 8246 12742
# Contour Area: 46441587.0
# patches extracted: 30
# Bounding Box: 2320 2356 7320 3511
# Contour Area: 9576260.5
# patches extracted: 3
# Bounding Box: 37878 65 3718 11246
# Contour Area: 11925078.5
# patches extracted: 3
# Bounding Box: 47141 0 10880 11452
# Contour Area: 69336530.5
#  35%|███████████████████████████████▎                                                          | 8/23 [2:00:00<3:53:48, 935.26s/it]
# patches extracted: 38
# [D] Elapsed(Generate patches): 215.4025752544403s
# [D] Elapsed(Tissue detection): 822.8442134857178s
# Bounding Box: 10890 40462 8401 4437
# Contour Area: 15449674.0
# patches extracted: 7
# Bounding Box: 42490 36023 2146 4099
# Contour Area: 3745735.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 44430 35739 6295 8217
# Contour Area: 24925244.0
# patches extracted: 15
# Bounding Box: 16873 33912 7418 6331
# Contour Area: 27410832.5
# patches extracted: 18
# Bounding Box: 21888 31895 3352 3967
# Contour Area: 5466198.0
# patches extracted: 2
# Bounding Box: 32178 30895 10027 14396
# Contour Area: 57697588.0
# patches extracted: 34
# Bounding Box: 13816 30799 3689 9379
# Contour Area: 15071608.0
# patches extracted: 7
# Bounding Box: 47918 30237 4195 6569
# Contour Area: 5251986.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 11222 27917 4066 5362
# Contour Area: 4583775.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 14946 27424 3241 3624
# Contour Area: 5897905.0
# patches extracted: 1
# Bounding Box: 36228 25660 3980 5132
# Contour Area: 7917458.5
# patches extracted: 3
# Bounding Box: 18761 25408 5960 7849
# Contour Area: 14461243.5
# patches extracted: 7
# Bounding Box: 24180 24351 4808 4695
# Contour Area: 6609836.0
# patches extracted: 2
# Bounding Box: 7924 22102 6025 6335
# Contour Area: 18669167.0
# patches extracted: 12
# Bounding Box: 22775 20353 4069 2203
# Contour Area: 4773387.5
# patches extracted: 3
# Bounding Box: 15870 20207 8129 5675
# Contour Area: 21624441.0
# patches extracted: 10
# Bounding Box: 47033 18131 5624 3535
# Contour Area: 10401169.5
# patches extracted: 5
# Bounding Box: 18509 16551 4864 4518
# Contour Area: 9842742.0
# patches extracted: 2
# Bounding Box: 24358 16057 9253 6914
# Contour Area: 36254046.0
# patches extracted: 26
# Bounding Box: 4107 13618 12155 9487
# Contour Area: 47949628.5
# patches extracted: 29
# Bounding Box: 24328 12384 24906 29357
# Contour Area: 197936977.0
# patches extracted: 119
# Bounding Box: 32575 9928 4927 6269
# Contour Area: 13478778.5
# patches extracted: 7
# Bounding Box: 38001 9482 4132 3140
# Contour Area: 7690378.0
# patches extracted: 4
# Bounding Box: 39197 8654 11346 9036
# Contour Area: 41334515.5
# patches extracted: 20
# Bounding Box: 8934 8375 17158 9184
# Contour Area: 84357235.0
# patches extracted: 61
# Bounding Box: 32511 7609 4783 3120
# Contour Area: 3827201.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 7018 7219 3618 3560
# Contour Area: 4312560.5
# patches extracted: 1
# Bounding Box: 27108 6165 5841 11143
# Contour Area: 23835839.0
# patches extracted: 13
# Bounding Box: 44181 3505 6302 5475
# Contour Area: 8464161.0
# patches extracted: 3
# Bounding Box: 12612 0 13429 9579
# Contour Area: 24160152.0
#  39%|███████████████████████████████████▏                                                      | 9/23 [2:16:26<3:41:52, 950.92s/it]
# patches extracted: 8
# [D] Elapsed(Generate patches): 162.44304490089417s
# [D] Elapsed(Tissue detection): 3852.4061830043793s
# Bounding Box: 47235 42862 6318 2428
# Contour Area: 4667678.5
# patches extracted: 1
# Bounding Box: 12884 41426 7635 3640
# Contour Area: 12873250.0
# patches extracted: 6
# Bounding Box: 24211 41346 6169 2771
# Contour Area: 7104961.5
# patches extracted: 3
# Bounding Box: 6856 40435 7889 2190
# Contour Area: 4022244.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 32219 39089 7321 5351
# Contour Area: 9522042.0
# patches extracted: 1
# Bounding Box: 33910 37509 6852 2692
# Contour Area: 7000578.5
# patches extracted: 1
# Bounding Box: 51418 37199 8423 7685
# Contour Area: 25854174.5
# patches extracted: 12
# Bounding Box: 38557 37116 5396 3966
# Contour Area: 7866270.5
# patches extracted: 3
# Bounding Box: 42431 36473 10798 7589
# Contour Area: 38581654.5
# patches extracted: 25
# Bounding Box: 46317 34395 5044 2464
# Contour Area: 3927340.0
# patches extracted: 1
# Bounding Box: 51118 30516 7482 6442
# Contour Area: 15037450.0
# patches extracted: 4
# Bounding Box: 19006 28120 14929 9495
# Contour Area: 45989258.5
# patches extracted: 18
# Bounding Box: 48737 27468 5841 5949
# Contour Area: 9730821.0
# patches extracted: 1
# Bounding Box: 55646 27398 3252 2803
# Contour Area: 3957640.0
# patches extracted: 2
# Bounding Box: 28596 24907 3432 3469
# Contour Area: 4048387.5
# patches extracted: 1
# Bounding Box: 51376 24627 4131 2991
# Contour Area: 4632948.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 20538 24261 8492 8758
# Contour Area: 29345300.0
# patches extracted: 14
# Bounding Box: 53277 23814 4948 3868
# Contour Area: 3291619.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 34458 22972 6283 4342
# Contour Area: 7187039.0
# patches extracted: 1
# Bounding Box: 57114 20822 4011 5008
# Contour Area: 5126034.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 12935 20729 8252 9097
# Contour Area: 33715690.5
# patches extracted: 13
# Bounding Box: 35980 18138 16489 18232
# Contour Area: 115894174.0
# patches extracted: 80
# Bounding Box: 27934 17421 11917 6369
# Contour Area: 31074612.0
# patches extracted: 15
# Bounding Box: 56473 16293 3955 4989
# Contour Area: 4644904.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 56528 12873 3629 2756
# Contour Area: 5518302.5
# patches extracted: 1
# Bounding Box: 47900 12350 4238 5658
# Contour Area: 12105582.5
# patches extracted: 6
# Bounding Box: 17426 10902 3378 5933
# Contour Area: 8917763.0
# patches extracted: 5
# Bounding Box: 9464 8469 3708 5120
# Contour Area: 8631001.5
# patches extracted: 4
# Bounding Box: 21038 7813 3970 4615
# Contour Area: 4877873.0
# patches extracted: 1
# Bounding Box: 11518 5766 3737 8329
# Contour Area: 8350503.0
# patches extracted: 2
# Bounding Box: 53929 5589 1875 6578
# Contour Area: 5658723.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 55305 4881 5743 7873
# Contour Area: 15890335.5
# patches extracted: 3
# Bounding Box: 32379 1521 6598 6644
# Contour Area: 11733450.0
# patches extracted: 1
# Bounding Box: 43311 1248 4465 5381
# Contour Area: 12597814.0
# patches extracted: 6
# Bounding Box: 38053 1063 5664 6247
# Contour Area: 9358462.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 59688 250 3707 2955
# Contour Area: 4447594.5
# patches extracted: 1
# Bounding Box: 19427 0 38209 25907
# Contour Area: 258880754.5
#  43%|██████████████████████████████████████▎                                                 | 10/23 [3:23:22<6:51:05, 1897.36s/it]
# patches extracted: 197
# Bounding Box: 12922 0 2658 3618
# Contour Area: 4286103.0
# patches extracted: 1
# [D] Elapsed(Generate patches): 164.08360362052917s
# [D] Elapsed(Tissue detection): 560.0422098636627s
# Bounding Box: 15645 34969 3755 4542
# Contour Area: 9886472.5
# patches extracted: 5
# Bounding Box: 16513 32530 2894 2779
# Contour Area: 4405120.5
# patches extracted: 1
# Bounding Box: 11085 31569 8059 8544
# Contour Area: 21881104.5
# patches extracted: 10
# Bounding Box: 4021 30203 8905 5944
# Contour Area: 24064245.5
# patches extracted: 14
# Bounding Box: 20083 24910 12597 11595
# Contour Area: 43902276.5
# patches extracted: 24
# Bounding Box: 26587 23351 5822 2863
# Contour Area: 7671629.0
# patches extracted: 2
# Bounding Box: 1497 23294 12604 7786
# Contour Area: 44323018.5
# patches extracted: 27
# Bounding Box: 8964 16584 4350 4764
# Contour Area: 7241839.5
# patches extracted: 1
# Bounding Box: 3543 15774 4272 4448
# Contour Area: 5939822.0
# patches extracted: 2
# Bounding Box: 3519 11540 5089 2715
# Contour Area: 4288658.5
# patches extracted: 1
# Bounding Box: 25450 10928 12055 12664
# Contour Area: 47194942.0
# patches extracted: 21
# Bounding Box: 10909 8632 14438 20474
# Contour Area: 110267075.0
# patches extracted: 56
# Bounding Box: 23204 6665 4836 7572
# Contour Area: 6657550.0
# patches extracted: 1
# Bounding Box: 2951 4949 3984 7290
# Contour Area: 9194896.5
#  48%|██████████████████████████████████████████                                              | 11/23 [3:33:47<5:01:35, 1508.00s/it]
# patches extracted: 2
# [D] Elapsed(Generate patches): 65.007568359375s
# [D] Elapsed(Tissue detection): 331.0749638080597s
# Bounding Box: 11204 33761 13343 6355
# Contour Area: 42163375.0
# patches extracted: 30
# Bounding Box: 26339 32355 4477 2517
# Contour Area: 4181460.0
# patches extracted: 1
# Bounding Box: 20433 31445 3485 1890
# Contour Area: 3386221.5
# patches extracted: 1
# Bounding Box: 49404 30310 8060 6938
# Contour Area: 24231058.0
# patches extracted: 10
# Bounding Box: 32670 30195 4557 7949
# Contour Area: 10404231.0
# patches extracted: 4
# Bounding Box: 23960 29641 8663 2777
# Contour Area: 10647848.0
# patches extracted: 4
# Bounding Box: 56641 28555 3194 3684
# Contour Area: 6676680.5
# patches extracted: 4
# Bounding Box: 12430 28169 4671 2977
# Contour Area: 7779914.5
# patches extracted: 4
# Bounding Box: 36260 27990 5297 2344
# Contour Area: 6775458.0
# patches extracted: 4
# Bounding Box: 20518 26434 6580 2265
# Contour Area: 7418737.5
# patches extracted: 4
# Bounding Box: 39460 23010 12965 17559
# Contour Area: 119511999.5
# patches extracted: 89
# Bounding Box: 26336 20154 4710 3624
# Contour Area: 7693371.0
# patches extracted: 4
# Bounding Box: 15285 19057 7209 8389
# Contour Area: 30251284.5
# patches extracted: 19
# Bounding Box: 46693 18082 6888 6884
# Contour Area: 26690812.5
# patches extracted: 17
# Bounding Box: 1605 16305 4032 5821
# Contour Area: 14534777.5
# patches extracted: 8
# Bounding Box: 17218 15558 3188 3798
# Contour Area: 7134169.0
# patches extracted: 4
# Bounding Box: 26006 14931 4663 5546
# Contour Area: 15737715.0
# patches extracted: 9
# Bounding Box: 31430 12864 6170 10714
# Contour Area: 36802071.5
# patches extracted: 25
# Bounding Box: 8118 12261 8354 15998
# Contour Area: 79382142.5
# patches extracted: 58
# Bounding Box: 30590 11944 2037 4641
# Contour Area: 4628790.0
# patches extracted: 1
# Bounding Box: 20977 11696 5285 7009
# Contour Area: 19804515.0
# patches extracted: 12
# Bounding Box: 39629 7874 7212 8786
# Contour Area: 34382472.5
# patches extracted: 22
# Bounding Box: 38081 4906 2521 5035
# Contour Area: 5583483.5
# patches extracted: 1
# Bounding Box: 41185 3151 5027 5550
# Contour Area: 11348428.5
# patches extracted: 4
# Bounding Box: 48841 2906 8441 18136
# Contour Area: 74320948.0
# patches extracted: 56
# Bounding Box: 20246 1048 15295 4808
# Contour Area: 45976066.0
# patches extracted: 32
# Bounding Box: 43834 0 4186 2986
# Contour Area: 5960772.5
#  52%|█████████████████████████████████████████████▉                                          | 12/23 [3:42:04<3:40:05, 1200.46s/it]
# patches extracted: 2
# [D] Elapsed(Generate patches): 165.89232277870178s
# [D] Elapsed(Tissue detection): 556.6285216808319s
# Bounding Box: 37311 43310 3875 1905
# Contour Area: 3397946.0
# patches extracted: 2
# Bounding Box: 41275 39403 3976 3621
# Contour Area: 7440263.5
# patches extracted: 4
# Bounding Box: 25556 38030 3332 2434
# Contour Area: 3851012.5
# patches extracted: 1
# Bounding Box: 27408 37609 5574 6033
# Contour Area: 14404670.0
# patches extracted: 8
# Bounding Box: 10121 37526 2745 4033
# Contour Area: 5971637.5
# patches extracted: 3
# Bounding Box: 35960 37359 4307 5840
# Contour Area: 13799201.5
# patches extracted: 8
# Bounding Box: 29847 36198 4931 2374
# Contour Area: 4198284.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 16401 35130 4571 6960
# Contour Area: 13767555.5
# patches extracted: 7
# Bounding Box: 22441 34221 5045 5846
# Contour Area: 12148524.0
# patches extracted: 6
# Bounding Box: 32505 33445 5847 4257
# Contour Area: 13940822.5
# patches extracted: 7
# Bounding Box: 47514 33407 3712 2187
# Contour Area: 4303788.0
# patches extracted: 3
# Bounding Box: 11749 32687 6085 4095
# Contour Area: 10221775.5
# patches extracted: 4
# Bounding Box: 40778 30654 5662 8060
# Contour Area: 13941372.5
# patches extracted: 7
# Bounding Box: 27113 30572 2696 3991
# Contour Area: 3623456.5
# patches extracted: 1
# Bounding Box: 55394 29135 3876 3540
# Contour Area: 8809340.0
# patches extracted: 5
# Bounding Box: 9734 27148 2479 4674
# Contour Area: 5895865.0
# patches extracted: 3
# Bounding Box: 46487 26577 6935 6711
# Contour Area: 21137449.5
# patches extracted: 14
# Bounding Box: 28363 26359 7724 8477
# Contour Area: 29252700.5
# patches extracted: 15
# Bounding Box: 3962 25856 6309 10158
# Contour Area: 25758657.0
# patches extracted: 16
# Bounding Box: 55672 25601 3647 3115
# Contour Area: 5202299.5
# patches extracted: 2
# Bounding Box: 17599 25428 3743 9527
# Contour Area: 14904247.0
# patches extracted: 7
# Bounding Box: 43995 24655 3572 6646
# Contour Area: 11572298.0
# patches extracted: 5
# Bounding Box: 12278 24138 3714 4364
# Contour Area: 9016967.0
# patches extracted: 3
# Bounding Box: 50976 22177 3196 3208
# Contour Area: 4628824.5
# patches extracted: 3
# Bounding Box: 1690 20646 2706 9146
# Contour Area: 6546841.0
# patches extracted: 2
# Bounding Box: 23297 18700 9194 13102
# Contour Area: 55862969.0
# patches extracted: 37
# Bounding Box: 37058 18583 6632 10307
# Contour Area: 30573482.0
# patches extracted: 21
# Bounding Box: 15635 18453 3734 5945
# Contour Area: 12862823.5
# patches extracted: 7
# Bounding Box: 48002 18110 5934 3467
# Contour Area: 8041231.0
# patches extracted: 3
# Bounding Box: 8151 18036 5347 6828
# Contour Area: 21053480.5
# patches extracted: 15
# Bounding Box: 53189 17548 5775 4770
# Contour Area: 8364913.0
# patches extracted: 2
# Bounding Box: 41636 16980 2769 3451
# Contour Area: 4291874.0
# patches extracted: 1
# Bounding Box: 31120 16475 7214 9585
# Contour Area: 27033786.5
# patches extracted: 18
# Bounding Box: 2940 15457 4064 4041
# Contour Area: 7414168.5
# patches extracted: 4
# Bounding Box: 27222 13243 3263 4388
# Contour Area: 7683472.5
# patches extracted: 5
# Bounding Box: 7169 12810 3122 2908
# Contour Area: 4120430.0
# patches extracted: 1
# Bounding Box: 35612 10825 10725 8168
# Contour Area: 31510802.0
# patches extracted: 16
# Bounding Box: 20917 7459 8308 12751
# Contour Area: 57039629.0
# patches extracted: 39
# Bounding Box: 39626 6846 6741 4965
# Contour Area: 18132678.5
# patches extracted: 9
# Bounding Box: 33946 6190 5696 4693
# Contour Area: 14642036.0
# patches extracted: 8
# Bounding Box: 22602 5738 4355 1703
# Contour Area: 4753945.5
# patches extracted: 1
# Bounding Box: 12776 5492 4361 5219
# Contour Area: 13630882.5
# patches extracted: 10
# Bounding Box: 36408 4210 3823 3123
# Contour Area: 6040787.0
# patches extracted: 2
# Bounding Box: 28185 2683 4643 5414
# Contour Area: 14363348.0
# patches extracted: 6
# Bounding Box: 10843 895 2625 4381
# Contour Area: 4024927.5
# patches extracted: 1
# Bounding Box: 26576 0 9096 5098
# Contour Area: 12291399.5
#  57%|█████████████████████████████████████████████████▋                                      | 13/23 [3:53:23<2:53:43, 1042.31s/it]
# patches extracted: 4
# [D] Elapsed(Generate patches): 121.71003580093384s
# [D] Elapsed(Tissue detection): 2957.2587699890137s
# Bounding Box: 29994 42216 3913 2469
# Contour Area: 3983074.5
# patches extracted: 1
# Bounding Box: 35783 39203 3798 5071
# Contour Area: 7534081.0
# patches extracted: 3
# Bounding Box: 14386 38526 2874 3979
# Contour Area: 4629188.0
# patches extracted: 2
# Bounding Box: 22913 32629 10476 12673
# Contour Area: 56038781.5
# patches extracted: 35
# Bounding Box: 5073 29942 3830 5479
# Contour Area: 10950766.5
# patches extracted: 4
# Bounding Box: 49424 29890 4452 2692
# Contour Area: 3703832.5
# patches extracted: 1
# Bounding Box: 11395 28622 4385 5480
# Contour Area: 13282882.5
# patches extracted: 9
# Bounding Box: 1529 28553 4429 4185
# Contour Area: 4663585.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 42356 28458 10695 13982
# Contour Area: 69372888.0
# patches extracted: 54
# Bounding Box: 21395 22462 8856 10162
# Contour Area: 22323587.0
# patches extracted: 5
# Bounding Box: 30309 22044 10766 16706
# Contour Area: 74187832.5
# patches extracted: 45
# Bounding Box: 14658 19875 8391 10543
# Contour Area: 27694166.5
# patches extracted: 10
# Bounding Box: 26186 19436 4509 4432
# Contour Area: 7869515.5
# patches extracted: 3
# Bounding Box: 35098 18270 3362 2693
# Contour Area: 3702724.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 42247 17626 14181 11897
# Contour Area: 96429817.0
# patches extracted: 77
# Bounding Box: 3458 16724 7636 9271
# Contour Area: 18232644.0
# patches extracted: 4
# Bounding Box: 6968 11064 7088 6946
# Contour Area: 21450158.0
# patches extracted: 11
# Bounding Box: 14217 10452 3682 6723
# Contour Area: 6864226.5
# patches extracted: 1
# Bounding Box: 39060 10118 6910 6266
# Contour Area: 27950287.0
# patches extracted: 20
# Bounding Box: 3219 9044 5439 3905
# Contour Area: 9779386.0
# patches extracted: 3
# Bounding Box: 28493 8877 11728 10840
# Contour Area: 39691093.0
# patches extracted: 22
# Bounding Box: 52339 8008 4384 4539
# Contour Area: 9566725.5
# patches extracted: 3
# Bounding Box: 11974 7578 3102 4130
# Contour Area: 5598920.5
# patches extracted: 2
# Bounding Box: 32077 6393 4588 3500
# Contour Area: 4686870.5
# patches extracted: 1
# Bounding Box: 46325 5769 6051 8586
# Contour Area: 24424155.5
# patches extracted: 13
# Bounding Box: 51832 5297 2918 3109
# Contour Area: 4604571.0
# patches extracted: 1
# Bounding Box: 24107 4521 6310 8590
# Contour Area: 14794384.5
#  61%|█████████████████████████████████████████████████████▌                                  | 14/23 [4:44:51<4:09:02, 1660.29s/it]
# patches extracted: 5
# Bounding Box: 13552 3694 7267 6317
# Contour Area: 4739442.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 37509 3130 2593 4015
# Contour Area: 3852123.5
# patches extracted: 1
# [D] Elapsed(Generate patches): 130.93390369415283s
# [D] Elapsed(Tissue detection): 1593.6118836402893s
# Bounding Box: 0 38748 3221 2933
# Contour Area: 6207584.0
# patches extracted: 3
# Bounding Box: 46276 35648 6666 7484
# Contour Area: 34894536.0
# patches extracted: 27
# Bounding Box: 0 35148 5693 7013
# Contour Area: 11859419.5
# patches extracted: 4
# Bounding Box: 22269 31777 4598 6186
# Contour Area: 15774737.0
# patches extracted: 11
# Bounding Box: 30464 30677 12642 13968
# Contour Area: 97211760.5
# patches extracted: 80
# Bounding Box: 43167 30550 3730 7363
# Contour Area: 13293135.0
# patches extracted: 7
# Bounding Box: 23306 28665 3525 1948
# Contour Area: 3689371.0
# patches extracted: 1
# Bounding Box: 2585 28467 18357 7889
# Contour Area: 68268142.5
# patches extracted: 49
# Bounding Box: 37367 26136 5785 5587
# Contour Area: 18966478.0
# patches extracted: 13
# Bounding Box: 43907 24481 4983 5837
# Contour Area: 10657678.0
# patches extracted: 4
# Bounding Box: 13371 23555 8486 5914
# Contour Area: 17132313.5
# patches extracted: 9
# Bounding Box: 39960 20796 6732 7112
# Contour Area: 18832820.0
# patches extracted: 12
# Bounding Box: 14582 20653 5037 4230
# Contour Area: 12902991.0
# patches extracted: 8
# Bounding Box: 45652 20190 6679 14032
# Contour Area: 38523456.5
# patches extracted: 28
# Bounding Box: 47419 19526 4171 3393
# Contour Area: 5868377.5
# patches extracted: 1
# Bounding Box: 15605 17566 25279 26079
# Contour Area: 207100158.0
# patches extracted: 141
# Bounding Box: 4565 17318 9088 12762
# Contour Area: 31767267.0
# patches extracted: 17
# Bounding Box: 20319 17296 10246 11704
# Contour Area: 72571826.0
# patches extracted: 56
# Bounding Box: 30012 17282 2231 3678
# Contour Area: 3174920.0
# patches extracted: 2
# Bounding Box: 40804 17214 6658 7346
# Contour Area: 24025068.5
# patches extracted: 15
# Bounding Box: 27756 14962 2634 2995
# Contour Area: 3996653.0
# patches extracted: 1
# Bounding Box: 14927 14574 3513 5669
# Contour Area: 13681485.0
# patches extracted: 11
# Bounding Box: 43160 11275 7189 4445
# Contour Area: 11865725.5
# patches extracted: 8
# Bounding Box: 8150 11261 7037 12799
# Contour Area: 46981824.0
# patches extracted: 28
# Bounding Box: 38015 7655 4015 3719
# Contour Area: 9307765.0
# patches extracted: 4
# Bounding Box: 2560 7644 2619 3665
# Contour Area: 4640611.0
# patches extracted: 2
# Bounding Box: 12107 7413 5901 6179
# Contour Area: 17556229.0
# patches extracted: 8
# Bounding Box: 46475 6816 2645 3295
# Contour Area: 4550339.0
# patches extracted: 3
# Bounding Box: 14931 5958 13337 9623
# Contour Area: 47835226.5
# patches extracted: 31
# Bounding Box: 4455 3354 4980 7907
# Contour Area: 21183835.0
# patches extracted: 10
# Bounding Box: 28553 2747 14337 14362
# Contour Area: 91314013.5
# patches extracted: 67
# Bounding Box: 37256 2716 6893 5603
# Contour Area: 23518453.5
# patches extracted: 16
# Bounding Box: 23825 2128 7829 9665
# Contour Area: 39655751.0
#  65%|█████████████████████████████████████████████████████████▍                              | 15/23 [5:15:58<3:49:40, 1722.62s/it]
# patches extracted: 24
# [D] Elapsed(Generate patches): 273.3997383117676s
# [D] Elapsed(Tissue detection): 1038.1233360767365s
# Bounding Box: 45955 38952 4490 3214
# Contour Area: 5560131.0
# patches extracted: 3
# Bounding Box: 12889 36933 4965 6639
# Contour Area: 14869031.5
# patches extracted: 6
# Bounding Box: 52514 33334 3168 2299
# Contour Area: 3721647.5
# patches extracted: 2
# Bounding Box: 44797 32884 3276 2702
# Contour Area: 5513560.0
# patches extracted: 2
# Bounding Box: 29320 32090 15184 13290
# Contour Area: 93909716.0
# patches extracted: 60
# Bounding Box: 45207 30859 2455 2289
# Contour Area: 3364647.5
# patches extracted: 1
# Bounding Box: 48655 30551 6605 7743
# Contour Area: 25305606.5
# patches extracted: 16
# Bounding Box: 41892 29520 3340 5319
# Contour Area: 9966157.0
# patches extracted: 5
# Bounding Box: 27501 28996 7451 6012
# Contour Area: 27833661.5
# patches extracted: 20
# Bounding Box: 6013 28496 13095 8351
# Contour Area: 49352678.5
# patches extracted: 32
# Bounding Box: 18421 28146 5044 7419
# Contour Area: 17583926.5
# patches extracted: 9
# Bounding Box: 50408 27293 4154 3681
# Contour Area: 9890013.5
# patches extracted: 7
# Bounding Box: 34503 26651 4848 2910
# Contour Area: 7548082.0
# patches extracted: 2
# Bounding Box: 23193 25999 5353 6155
# Contour Area: 18869441.0
# patches extracted: 12
# Bounding Box: 14534 25073 5712 4211
# Contour Area: 12322585.5
# patches extracted: 8
# Bounding Box: 46443 23729 6797 6525
# Contour Area: 20325912.0
# patches extracted: 12
# Bounding Box: 38345 22089 8934 7640
# Contour Area: 22340727.0
# patches extracted: 8
# Bounding Box: 26575 22088 4539 5134
# Contour Area: 6875962.5
# patches extracted: 1
# Bounding Box: 11088 21252 6590 4921
# Contour Area: 14447618.5
# patches extracted: 7
# Bounding Box: 7135 19671 4088 5307
# Contour Area: 12714657.0
# patches extracted: 7
# Bounding Box: 26424 17659 2923 3079
# Contour Area: 3991069.5
# patches extracted: 1
# Bounding Box: 30333 17039 11438 10017
# Contour Area: 52086031.5
# patches extracted: 31
# Bounding Box: 48164 16781 7636 6603
# Contour Area: 30294383.0
# patches extracted: 19
# Bounding Box: 11398 15789 5892 4662
# Contour Area: 17602815.5
# patches extracted: 11
# Bounding Box: 38413 15193 4034 5769
# Contour Area: 14958966.0
# patches extracted: 9
# Bounding Box: 43496 13498 7596 7243
# Contour Area: 26188663.0
# patches extracted: 19
# Bounding Box: 20927 13072 3361 2625
# Contour Area: 3637817.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 49369 11683 4118 3663
# Contour Area: 3436992.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 29503 10679 7388 5465
# Contour Area: 18527525.0
# patches extracted: 12
# Bounding Box: 53747 10645 4704 4395
# Contour Area: 4358034.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 42505 9750 3280 3356
# Contour Area: 5382784.0
# patches extracted: 3
# Bounding Box: 20448 8480 2834 5214
# Contour Area: 5086518.0
# patches extracted: 1
# Bounding Box: 8994 6659 7756 8982
# Contour Area: 17903762.5
# patches extracted: 3
# Bounding Box: 40867 6374 3143 3463
# Contour Area: 5802689.5
# patches extracted: 2
# Bounding Box: 16161 4403 4520 8652
# Contour Area: 17903151.5
# patches extracted: 9
# Bounding Box: 25962 2375 3837 7205
# Contour Area: 11804317.0
# patches extracted: 6
# Bounding Box: 30797 933 10421 11404
# Contour Area: 44337395.0
# patches extracted: 26
# Bounding Box: 36601 688 6951 8155
# Contour Area: 26148437.5
# patches extracted: 17
# Bounding Box: 17897 209 7004 8397
# Contour Area: 33779804.0
# patches extracted: 21
# Bounding Box: 8435 0 6231 7146
# Contour Area: 17459085.5
#  70%|█████████████████████████████████████████████████████████████▏                          | 16/23 [5:35:54<3:02:27, 1563.99s/it]
# patches extracted: 8
# [D] Elapsed(Generate patches): 157.41910028457642s
# [D] Elapsed(Tissue detection): 858.5183057785034s
# Bounding Box: 18109 41603 6251 3778
# Contour Area: 12616590.0
# patches extracted: 6
# Bounding Box: 25748 39192 2860 4737
# Contour Area: 6467317.0
# patches extracted: 1
# Bounding Box: 24047 36098 2003 3593
# Contour Area: 4612481.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 48555 33899 4933 5621
# Contour Area: 11311250.5
# patches extracted: 5
# Bounding Box: 20452 30756 5474 5718
# Contour Area: 17711226.5
# patches extracted: 12
# Bounding Box: 26632 30187 2869 3603
# Contour Area: 5967006.5
# patches extracted: 3
# Bounding Box: 51579 27548 2995 3097
# Contour Area: 4246823.0
# patches extracted: 1
# Bounding Box: 2983 27049 7035 6094
# Contour Area: 29761274.5
# patches extracted: 22
# Bounding Box: 12982 26146 12689 13240
# Contour Area: 57558050.0
# patches extracted: 35
# Bounding Box: 34234 23844 19297 15847
# Contour Area: 118086483.0
# patches extracted: 83
# Bounding Box: 26677 22348 13294 17815
# Contour Area: 83852806.0
# patches extracted: 54
# Bounding Box: 22323 21138 4871 3640
# Contour Area: 8792007.0
# patches extracted: 6
# Bounding Box: 14768 20977 7636 8031
# Contour Area: 25302682.0
# patches extracted: 16
# Bounding Box: 7884 20470 8303 7262
# Contour Area: 37660193.0
# patches extracted: 26
# Bounding Box: 26051 18240 12962 4937
# Contour Area: 21470289.5
# patches extracted: 10
# Bounding Box: 41875 16082 4266 3082
# Contour Area: 5221017.5
# patches extracted: 1
# Bounding Box: 38176 15725 6170 11652
# Contour Area: 35880776.0
# patches extracted: 23
# Bounding Box: 44990 14337 5766 6971
# Contour Area: 16527184.5
# patches extracted: 7
# Bounding Box: 17648 14177 6758 8531
# Contour Area: 26201710.5
# patches extracted: 12
# Bounding Box: 23629 13792 4525 4018
# Contour Area: 7417191.5
# patches extracted: 3
# Bounding Box: 29192 12628 10713 8200
# Contour Area: 43499853.0
# patches extracted: 31
# Bounding Box: 31104 10537 2114 2645
# Contour Area: 3684604.0
# patches extracted: 1
# Bounding Box: 5458 7132 7097 6520
# Contour Area: 26547735.5
# patches extracted: 19
# Bounding Box: 33042 5905 10984 10180
# Contour Area: 54248108.0
# patches extracted: 36
# Bounding Box: 20704 4608 5614 9166
# Contour Area: 29320837.5
# patches extracted: 18
# Bounding Box: 12831 2472 8560 15943
# Contour Area: 89599241.0
# patches extracted: 69
# Bounding Box: 33334 549 3813 2812
# Contour Area: 4526907.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 30004 228 3514 3394
# Contour Area: 4031070.5
# patches extracted: 1
# Bounding Box: 4907 118 6167 7247
# Contour Area: 23153193.0
# patches extracted: 14
# Bounding Box: 24291 0 9096 9965
# Contour Area: 52517109.5
#  74%|█████████████████████████████████████████████████████████████████                       | 17/23 [5:53:45<2:21:35, 1415.94s/it]
# patches extracted: 37
# Bounding Box: 16634 0 4335 3442
# Contour Area: 3482534.0
# patches extracted: 0
# StopIteration Error
# [D] Elapsed(Generate patches): 213.07622051239014s
# [D] Elapsed(Tissue detection): 445.85901403427124s
# Bounding Box: 40501 32760 3931 3097
# Contour Area: 3461011.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 11071 30678 3320 3210
# Contour Area: 3410054.0
# patches extracted: 1
# Bounding Box: 39327 30018 4398 4387
# Contour Area: 8053249.5
# patches extracted: 4
# Bounding Box: 12159 27188 9543 7710
# Contour Area: 35696765.5
# patches extracted: 23
# Bounding Box: 17140 25326 8981 4680
# Contour Area: 17969279.0
# patches extracted: 9
# Bounding Box: 28278 25084 11877 11120
# Contour Area: 59269647.0
# patches extracted: 40
# Bounding Box: 9184 24785 3289 6736
# Contour Area: 12634070.0
# patches extracted: 7
# Bounding Box: 42081 20026 7962 11314
# Contour Area: 55300332.0
# patches extracted: 38
# Bounding Box: 21258 18723 4779 5923
# Contour Area: 10318729.5
# patches extracted: 5
# Bounding Box: 3791 14918 9168 10027
# Contour Area: 43796531.5
# patches extracted: 29
# Bounding Box: 17978 12891 6302 5299
# Contour Area: 15157234.5
# patches extracted: 9
# Bounding Box: 12797 12844 5072 6386
# Contour Area: 16713327.0
# patches extracted: 9
# Bounding Box: 27997 12180 2389 2491
# Contour Area: 3146217.5
# patches extracted: 2
# Bounding Box: 35089 10004 4575 6452
# Contour Area: 11500841.0
# patches extracted: 5
# Bounding Box: 25555 9173 21887 18055
# Contour Area: 157497905.5
# patches extracted: 93
# Bounding Box: 30934 6936 5777 4877
# Contour Area: 12091456.0
# patches extracted: 6
# Bounding Box: 35299 6758 6902 6582
# Contour Area: 14330015.0
# patches extracted: 3
# Bounding Box: 43390 6631 3369 3400
# Contour Area: 3777778.5
# patches extracted: 1
# Bounding Box: 2213 6082 10420 8912
# Contour Area: 52771126.5
# patches extracted: 36
# Bounding Box: 14538 5468 3357 5221
# Contour Area: 9834880.5
# patches extracted: 5
# Bounding Box: 18869 3893 11272 7613
# Contour Area: 50035832.0
#  78%|████████████████████████████████████████████████████████████████████▊                   | 18/23 [6:03:40<1:37:25, 1169.12s/it]
# patches extracted: 37
# [D] Elapsed(Generate patches): 148.61663675308228s
# [D] Elapsed(Tissue detection): 267.122935295105s
# Bounding Box: 10360 25029 5949 3438
# Contour Area: 9658071.5
# patches extracted: 4
# Bounding Box: 2910 23427 5497 6653
# Contour Area: 17457556.0
# patches extracted: 11
# Bounding Box: 39015 23184 5979 3464
# Contour Area: 9563511.0
# patches extracted: 4
# Bounding Box: 21593 22864 3035 3569
# Contour Area: 5701359.0
# patches extracted: 3
# Bounding Box: 9020 21578 6203 3476
# Contour Area: 9375243.5
# patches extracted: 6
# Bounding Box: 31496 21273 5455 6645
# Contour Area: 17194427.0
# patches extracted: 8
# Bounding Box: 50267 21181 3087 3467
# Contour Area: 5549836.5
# patches extracted: 3
# Bounding Box: 16906 17728 9809 9435
# Contour Area: 35054493.5
# patches extracted: 22
# Bounding Box: 11794 16191 5598 7033
# Contour Area: 26401668.5
# patches extracted: 17
# Bounding Box: 45671 16041 9799 9290
# Contour Area: 34400513.0
# patches extracted: 21
# Bounding Box: 37763 14430 8434 8779
# Contour Area: 35161552.0
# patches extracted: 23
# Bounding Box: 16530 13026 8199 8470
# Contour Area: 29521026.0
# patches extracted: 20
# Bounding Box: 45468 11334 7485 8009
# Contour Area: 25268894.5
# patches extracted: 15
# Bounding Box: 2140 10534 6711 7796
# Contour Area: 32723456.5
# patches extracted: 25
# Bounding Box: 9329 9330 9173 7236
# Contour Area: 41559914.0
# patches extracted: 31
# Bounding Box: 30942 8600 6818 7750
# Contour Area: 32578772.0
# patches extracted: 24
# Bounding Box: 38188 7474 9118 7265
# Contour Area: 41220684.0
# patches extracted: 34
# Bounding Box: 2521 7401 4312 3756
# Contour Area: 7381608.0
# patches extracted: 2
# Bounding Box: 30077 5527 5598 3761
# Contour Area: 9674952.5
# patches extracted: 5
# Bounding Box: 7013 4133 2541 4823
# Contour Area: 5956585.0
# patches extracted: 3
# Bounding Box: 16941 3738 6723 5504
# Contour Area: 17105834.0
# patches extracted: 11
# Bounding Box: 10538 3339 6512 6140
# Contour Area: 23778700.5
# patches extracted: 18
# Bounding Box: 35655 2281 2790 4797
# Contour Area: 6370720.5
# patches extracted: 1
# Bounding Box: 45743 1999 6848 5379
# Contour Area: 16933046.0
# patches extracted: 10
# Bounding Box: 39420 1510 6464 6064
# Contour Area: 23305699.5
#  83%|█████████████████████████████████████████████████████████████████████████▌               | 19/23 [6:10:09<1:02:19, 934.90s/it]
# patches extracted: 17
# [D] Elapsed(Generate patches): 122.04819798469543s
# [D] Elapsed(Tissue detection): 328.954558134079s
# Bounding Box: 39443 30105 5493 5808
# Contour Area: 9446936.5
# patches extracted: 3
# Bounding Box: 20393 29114 7195 10980
# Contour Area: 36206488.0
# patches extracted: 25
# Bounding Box: 16738 26295 6452 6531
# Contour Area: 26579303.0
# patches extracted: 19
# Bounding Box: 11285 21222 5376 16453
# Contour Area: 23831721.0
# patches extracted: 7
# Bounding Box: 12636 20818 5219 6610
# Contour Area: 8386626.0
# patches extracted: 2
# Bounding Box: 33635 19216 9106 6559
# Contour Area: 25069241.0
# patches extracted: 16
# Bounding Box: 24021 19186 12792 13877
# Contour Area: 53838917.5
# patches extracted: 36
# Bounding Box: 43779 19110 3920 3170
# Contour Area: 4911020.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 10192 18799 2915 3290
# Contour Area: 3786774.0
# patches extracted: 1
# Bounding Box: 18413 18633 8844 6925
# Contour Area: 30060475.0
# patches extracted: 17
# Bounding Box: 30123 17925 4804 3686
# Contour Area: 8496421.0
# patches extracted: 5
# Bounding Box: 26499 16581 4573 5461
# Contour Area: 7158860.0
# patches extracted: 0
# StopIteration Error
# Bounding Box: 21217 15065 4573 4151
# Contour Area: 7894832.0
# patches extracted: 2
# Bounding Box: 33340 10491 4479 8009
# Contour Area: 15612256.5
# patches extracted: 10
# Bounding Box: 43127 9977 3411 6231
# Contour Area: 8009434.5
# patches extracted: 3
# Bounding Box: 28486 9252 2624 3880
# Contour Area: 3816922.0
# patches extracted: 2
# Bounding Box: 37750 8008 4136 7688
# Contour Area: 16146688.5
# patches extracted: 8
# Bounding Box: 21304 7779 8389 9394
# Contour Area: 22559584.5
# patches extracted: 8
# Bounding Box: 30924 4547 6961 6116
# Contour Area: 14772059.0
#  87%|███████████████████████████████████████████████████████████████████████████████▏           | 20/23 [6:16:41<38:35, 771.72s/it]
# patches extracted: 5
# [D] Elapsed(Generate patches): 62.369678258895874s
# [D] Elapsed(Tissue detection): 916.1626889705658s
# Bounding Box: 33144 43628 3720 1975
# Contour Area: 4198903.0
# patches extracted: 2
# Bounding Box: 44037 37456 11029 8147
# Contour Area: 41095866.5
# patches extracted: 20
# Bounding Box: 33764 37313 10478 8290
# Contour Area: 33750234.0
# patches extracted: 19
# Bounding Box: 17675 37003 7684 4839
# Contour Area: 21517736.5
# patches extracted: 11
# Bounding Box: 51787 32853 3722 3459
# Contour Area: 5993406.5
# patches extracted: 1
# Bounding Box: 63126 31452 3762 2092
# Contour Area: 3066365.5
# patches extracted: 1
# Bounding Box: 38101 31151 11899 6407
# Contour Area: 23863510.0
# patches extracted: 8
# Bounding Box: 6400 29139 10249 14085
# Contour Area: 75249700.0
# patches extracted: 55
# Bounding Box: 15880 29111 3283 5190
# Contour Area: 5923255.0
# patches extracted: 2
# Bounding Box: 13516 28785 3708 8021
# Contour Area: 10624517.5
# patches extracted: 2
# Bounding Box: 29002 28580 8195 10118
# Contour Area: 41469667.5
# patches extracted: 24
# Bounding Box: 58580 28545 4065 6923
# Contour Area: 15106662.5
# patches extracted: 7
# Bounding Box: 46692 24837 10911 8301
# Contour Area: 51739650.5
# patches extracted: 32
# Bounding Box: 18751 24767 8785 10102
# Contour Area: 47054456.0
# patches extracted: 29
# Bounding Box: 38798 24458 7601 7054
# Contour Area: 27249103.5
# patches extracted: 19
# Bounding Box: 1125 23743 2727 4034
# Contour Area: 6230760.0
# patches extracted: 4
# Bounding Box: 58559 22772 7088 6888
# Contour Area: 11813065.5
# patches extracted: 3
# Bounding Box: 63875 21658 2622 5456
# Contour Area: 7939593.5
# patches extracted: 5
# Bounding Box: 44469 19767 6585 3865
# Contour Area: 9612163.0
# patches extracted: 5
# Bounding Box: 38394 19102 3415 2811
# Contour Area: 4704794.5
# patches extracted: 2
# Bounding Box: 7592 18632 3728 6272
# Contour Area: 10492591.0
# patches extracted: 6
# Bounding Box: 54906 17813 8316 6127
# Contour Area: 19556451.5
# patches extracted: 8
# Bounding Box: 33783 17764 5198 7572
# Contour Area: 13981359.0
# patches extracted: 7
# Bounding Box: 30283 17068 4336 11151
# Contour Area: 15139080.0
# patches extracted: 4
# Bounding Box: 62708 14727 5129 6744
# Contour Area: 17043380.0
# patches extracted: 10
# Bounding Box: 10461 14595 7043 9619
# Contour Area: 41530506.0
# patches extracted: 28
# Bounding Box: 38103 11414 8760 7999
# Contour Area: 45561606.0
# patches extracted: 32
# Bounding Box: 55642 10229 6614 7696
# Contour Area: 20809677.0
# patches extracted: 13
# Bounding Box: 16271 7138 6557 7153
# Contour Area: 22732707.0
# patches extracted: 12
# Bounding Box: 38931 6289 6057 4766
# Contour Area: 9148588.5
# patches extracted: 4
# Bounding Box: 48217 5505 4354 3266
# Contour Area: 8273684.0
# patches extracted: 4
# Bounding Box: 47491 4705 10762 9626
# Contour Area: 45273690.5
# patches extracted: 26
# Bounding Box: 28362 2379 6643 9660
# Contour Area: 35936880.0
# patches extracted: 25
# Bounding Box: 10440 1938 5135 4798
# Contour Area: 13701428.5
# patches extracted: 9
# Bounding Box: 36565 807 6392 7936
# Contour Area: 25523809.5
# patches extracted: 15
# Bounding Box: 49335 802 5638 3768
# Contour Area: 4754527.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 50365 0 5522 4148
# Contour Area: 6058200.5
# patches extracted: 2
# Bounding Box: 43664 0 5433 6198
# Contour Area: 14573963.5
# patches extracted: 6
# Bounding Box: 21333 0 8771 6925
# Contour Area: 18693452.5
# patches extracted: 8
# Bounding Box: 15038 0 4779 5570
# Contour Area: 14350969.0
#  91%|███████████████████████████████████████████████████████████████████████████████████        | 21/23 [6:34:59<28:59, 869.89s/it]
# patches extracted: 7
# [D] Elapsed(Generate patches): 182.508807182312s
# [D] Elapsed(Tissue detection): 755.0467712879181s
# Bounding Box: 40381 41154 4186 4146
# Contour Area: 9148433.5
# patches extracted: 4
# Bounding Box: 10791 34882 8943 7383
# Contour Area: 41452070.0
# patches extracted: 31
# Bounding Box: 6253 34129 2773 3063
# Contour Area: 4118782.0
# patches extracted: 2
# Bounding Box: 22218 32062 7098 7242
# Contour Area: 25419880.5
# patches extracted: 16
# Bounding Box: 53736 29161 4357 5373
# Contour Area: 9349941.0
# patches extracted: 3
# Bounding Box: 45666 25559 8758 14765
# Contour Area: 73582106.5
# patches extracted: 50
# Bounding Box: 8408 25393 6433 7540
# Contour Area: 23033198.5
# patches extracted: 15
# Bounding Box: 1063 24517 7637 9530
# Contour Area: 42404507.5
# patches extracted: 29
# Bounding Box: 47170 22073 9043 2879
# Contour Area: 13488400.5
# patches extracted: 8
# Bounding Box: 12273 20510 4347 4921
# Contour Area: 9516986.5
# patches extracted: 6
# Bounding Box: 14659 19237 31257 25270
# Contour Area: 350435835.0
# patches extracted: 276
# Bounding Box: 11176 15960 4266 3204
# Contour Area: 9793955.0
# patches extracted: 5
# Bounding Box: 2413 14674 10039 9047
# Contour Area: 53686598.5
# patches extracted: 42
# Bounding Box: 23633 13271 3558 5074
# Contour Area: 10638154.0
# patches extracted: 7
# Bounding Box: 39195 13017 16125 8387
# Contour Area: 69203541.5
# patches extracted: 49
# Bounding Box: 26034 11017 8512 11510
# Contour Area: 59775515.5
# patches extracted: 44
# Bounding Box: 34042 9768 4507 7755
# Contour Area: 20366261.0
# patches extracted: 13
# Bounding Box: 48087 9101 3309 3129
# Contour Area: 3907911.5
# patches extracted: 2
# Bounding Box: 16167 7817 5847 12564
# Contour Area: 43267132.5
# patches extracted: 31
# Bounding Box: 46006 7562 2997 3409
# Contour Area: 4463697.5
# patches extracted: 2
# Bounding Box: 9393 7158 4939 8710
# Contour Area: 13544649.0
# patches extracted: 3
# Bounding Box: 42641 6736 3073 2927
# Contour Area: 3234854.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 49215 5174 8277 11796
# Contour Area: 43459627.5
# patches extracted: 29
# Bounding Box: 23137 2967 8844 8784
# Contour Area: 49987895.0
# patches extracted: 38
# Bounding Box: 43510 2935 5060 5265
# Contour Area: 11207629.5
# patches extracted: 8
# Bounding Box: 28837 2543 4026 3257
# Contour Area: 6749986.5
# patches extracted: 2
# Bounding Box: 30981 208 11108 12917
# Contour Area: 53840638.5
#  96%|███████████████████████████████████████████████████████████████████████████████████████    | 22/23 [6:52:47<15:29, 929.24s/it]
# patches extracted: 34
# [D] Elapsed(Generate patches): 312.52991127967834s
# [D] Elapsed(Tissue detection): 356.36781668663025s
# Bounding Box: 11990 34613 3791 3821
# Contour Area: 5367006.5
# patches extracted: 1
# Bounding Box: 30906 33052 6033 3499
# Contour Area: 10261898.5
# patches extracted: 4
# Bounding Box: 27245 30246 3160 3887
# Contour Area: 5966048.5
# patches extracted: 1
# Bounding Box: 24044 30202 21970 11345
# Contour Area: 68353368.0
# patches extracted: 47
# Bounding Box: 3974 29976 7370 7571
# Contour Area: 12393151.0
# patches extracted: 4
# Bounding Box: 29066 28634 6659 3570
# Contour Area: 5456813.5
# patches extracted: 1
# Bounding Box: 16981 28035 3320 5583
# Contour Area: 7276438.0
# patches extracted: 3
# Bounding Box: 7906 27982 4271 6436
# Contour Area: 15222194.5
# patches extracted: 8
# Bounding Box: 12164 27171 4538 8290
# Contour Area: 8019693.5
# patches extracted: 1
# Bounding Box: 18798 25766 5958 10322
# Contour Area: 25287484.5
# patches extracted: 12
# Bounding Box: 6485 25446 2125 3380
# Contour Area: 3866508.0
# patches extracted: 1
# Bounding Box: 28838 25038 10898 5820
# Contour Area: 26401657.0
# patches extracted: 15
# Bounding Box: 38966 22535 8402 5034
# Contour Area: 20958392.0
# patches extracted: 12
# Bounding Box: 30375 18192 7847 7733
# Contour Area: 32686096.5
# patches extracted: 21
# Bounding Box: 36094 17256 5040 4832
# Contour Area: 11734393.5
# patches extracted: 6
# Bounding Box: 34562 15301 2727 1787
# Contour Area: 2934141.5
# patches extracted: 0
# StopIteration Error
# Bounding Box: 36376 10670 4867 4222
# Contour Area: 7258540.0
# patches extracted: 2
# Bounding Box: 26332 9377 4064 5422
# Contour Area: 11272832.0
# patches extracted: 7
# Bounding Box: 33564 7798 8550 7727
# Contour Area: 18673218.0
# patches extracted: 10
# Bounding Box: 9488 6855 23418 21312
# Contour Area: 201107151.5
# patches extracted: 156
# Bounding Box: 3511 3133 19603 15837
# Contour Area: 73348652.0
# patches extracted: 45
# Bounding Box: 25855 1258 10104 7799
# Contour Area: 44471063.0
# patches extracted: 32
# Bounding Box: 32827 1113 6686 7464
# Contour Area: 19759089.5
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 23/23 [7:01:17<00:00, 1099.04s/it]
# patches extracted: 12
# [D] Elapsed(Generate patches): 153.7496213912964s
# CPU times: user 6h 41min 5s, sys: 7min 35s, total: 6h 48min 40s
# Wall time: 7h 1min 17s
